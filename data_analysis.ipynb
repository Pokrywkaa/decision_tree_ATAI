# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import os

# %%
df = pd.read_csv('Life Expectancy Data.csv')

# %%
df.describe().applymap(lambda x: f"{x:0.1f}")
# Out:
#          Year Life expectancy  Adult Mortality infant deaths Alcohol  \
# count  2938.0           2928.0          2928.0        2938.0  2744.0
# mean   2007.5             69.2           164.8          30.3     4.6
# std       4.6              9.5           124.3         117.9     4.1
# min    2000.0             36.3             1.0           0.0     0.0
# 25%    2004.0             63.1            74.0           0.0     0.9
# 50%    2008.0             72.1           144.0           3.0     3.8
# 75%    2012.0             75.7           228.0          22.0     7.7
# max    2015.0             89.0           723.0        1800.0    17.9
#
#       percentage expenditure Hepatitis B  Measles     BMI  under-five deaths   \
# count                 2938.0      2385.0    2938.0  2904.0             2938.0
# mean                   738.3        80.9    2419.6    38.3               42.0
# std                   1987.9        25.1   11467.3    20.0              160.4
# min                      0.0         1.0       0.0     1.0                0.0
# 25%                      4.7        77.0       0.0    19.3                0.0
# 50%                     64.9        92.0      17.0    43.5                4.0
# 75%                    441.5        97.0     360.2    56.2               28.0
# max                  19479.9        99.0  212183.0    87.3             2500.0
#
#         Polio Total expenditure Diphtheria   HIV/AIDS       GDP    Population  \
# count  2919.0            2712.0      2919.0    2938.0    2490.0        2286.0
# mean     82.6               5.9        82.3       1.7    7483.2    12753375.1
# std      23.4               2.5        23.7       5.1   14270.2    61012096.5
# min       3.0               0.4         2.0       0.1       1.7          34.0
# 25%      78.0               4.3        78.0       0.1     463.9      195793.2
# 50%      93.0               5.8        93.0       0.1    1766.9     1386542.0
# 75%      97.0               7.5        97.0       0.8    5910.8     7420359.0
# max      99.0              17.6        99.0      50.6  119172.7  1293859294.0
#
#        thinness  1-19 years  thinness 5-9 years  \
# count                2904.0              2904.0
# mean                    4.8                 4.9
# std                     4.4                 4.5
# min                     0.1                 0.1
# 25%                     1.6                 1.5
# 50%                     3.3                 3.3
# 75%                     7.2                 7.2
# max                    27.7                28.6
#
#       Income composition of resources Schooling
# count                          2771.0    2775.0
# mean                              0.6      12.0
# std                               0.2       3.4
# min                               0.0       0.0
# 25%                               0.5      10.1
# 50%                               0.7      12.3
# 75%                               0.8      14.3
# max                               0.9      20.7

# %%
sns.displot(df["Life expectancy "])
